# %%
import pandas as pd
data=pd.read_csv("framingham.csv")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
# 1st answer

# %%
male_data=data.query("male==1 and education==3.0 and heartRate>65")

# %%
male_data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 39       1   36        3.0              0         0.0     0.0
# 49       1   36        3.0              1        20.0     NaN
# 111      1   51        3.0              0         0.0     0.0
# 119      1   50        3.0              1        40.0     0.0
# 122      1   66        3.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4146     1   42        3.0              0         0.0     0.0
# 4178     1   41        3.0              1        30.0     0.0
# 4222     1   53        3.0              0         0.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 39                  0             0         0    180.0  111.0   73.0  27.78
# ...

# %%
# Repeat 1

# %%
female_data=data.query("male==0 and education==3.0 and heartRate>65")

# %%
female_data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4        0   46        3.0              1        23.0     0.0
# 23       0   52        3.0              1        20.0     0.0
# 28       0   61        3.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# 77       0   44        3.0              1        20.0     NaN
# ...    ...  ...        ...            ...         ...     ...
# 4188     0   44        3.0              0         0.0     0.0
# 4214     0   56        3.0              1         5.0     0.0
# 4216     0   59        3.0              1        20.0     0.0
# 4229     0   51        3.0              1        20.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...

# %%
# 6th answer

# %%
y=data["heartRate"]

# %%
x=data.drop(["heartRate"],axis=1)

# %%
x
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
# 7th answer

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
x_train.shape
# Out:
# (2826, 15)

# %%
x_train= x_train.fillna(x_train.mean())

# %%
x_train.shape
# Out:
# (2826, 15)

# %%
x_train.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
y_train=y_train.fillna(y_train.mean())

# %%
y_train.shape
# Out:
# (2826,)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-4.00373054, -0.12749235, -0.51077547,  1.30842867,  0.11118341,
#        -3.93636561, -0.14559129,  1.05987445, -0.69283387,  0.01442711,
#         0.05339334,  0.10262932,  0.04372452,  0.05319402,  0.05232586])

# %%
model.intercept_
# Out:
# 58.57161361600062

# %%
model.score(x_train,y_train)
# Out:
# 0.09424220568159869

# %%
y_test=y_test.fillna(y_test.mean())

# %%
x_test=x_test.fillna(x_test.mean())

# %%
model.score(x_test,y_test)
# Out:
# 0.07010795633752354

# %%
#Above Model is a underfit

# %%
# 3rd answer

# %%
#Regression:Regression is a technique used to model and analyze the relationships between variables and often times how they 
#contribute. A linear regression refers to a regression model that 
#is completely made up of linear variables. 
#It is of two types:
#Linear Regression
#Polynomial Regression

# %%
# 4th answer

# %%
#Overfit: It occurs when a statistical model fits exactly against its training data. When this happens, the algorithm 
#unfortunately cannot perform accurately against unseen data.

# %%
# 5th answer

# %%
# How to handle the overfit condition?
#Apply regularization , which comes down to adding a cost to the loss function.

# %%
# 7th answer

# %%
import pandas as pd

# %%
poly=pd.read_csv("poly_practice_2.csv")

# %%
poly
# Out:
#      x         y
# 0    1         4
# 1    2        20
# 2    3        86
# 3    4       262
# 4    5       632
# ..  ..       ...
# 84  85  52200712
# 85  86  54700904
# 86  87  57289850
# 87  88  59969626
# 88  89  62742332
#
# [89 rows x 2 columns]

# %%
y= poly["y"]

# %%
x=poly.drop("y",axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([580512.78993345])

# %%
model.intercept_
# Out:
# -13518855.865478745

# %%
model.score(x_train,y_train)
# Out:
# 0.752458319268784

# %%
model.score(x_test,y_test)
# Out:
# 0.7511716666318994

# %%
#This Model is Ideal
