# %%
df = pd.read_csv("LogisticData.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
y = df["dual_sim"]
x = df.drop("dual_sim",axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_train,y_train)
# Out:
# 0.5558889722430608

# %%
gnb.score(x_test,y_test)
# Out:
# 0.5097451274362819

# %%
df = pd.read_csv("LogisticData.csv")

# %%
df.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
y = df["four_g"]
x = df.drop("four_g",axis = 1)

# %%
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  int_memory  m_dep  \
# 0            842     0          2.2         0   1           7    0.6
# 1           1021     1          0.5         1   0          53    0.7
# 2            563     1          0.5         1   2          41    0.9
# 3            615     1          2.5         0   0          10    0.8
# 4           1821     1          1.2         0  13          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# ...

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: four_g, dtype: int64

# %%
x.shape
# Out:
# (2000, 20)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
x_train.shape
# Out:
# (1333, 20)

# %%
x_test.shape
# Out:
# (667, 20)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_train,y_train)
# Out:
# 0.7561890472618155

# %%
gnb.score(x_test,y_test)
# Out:
# 0.767616191904048

# %% [markdown]
# # 2nd Problem

# %%
import pandas as pd
data = pd.read_csv("Card_Defaulter.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 default student      balance       income
# 0           0      No      No   729.526495  44361.62507
# 1           1      No     Yes   817.180407  12106.13470
# 2           2      No      No  1073.549164  31767.13895
# 3           3      No      No   529.250605  35704.49394
# 4           4      No      No   785.655883  38463.49588

# %%
data = data.drop("Unnamed: 0",axis = 1)

# %%
data.head()
# Out:
#   default student      balance       income
# 0      No      No   729.526495  44361.62507
# 1      No     Yes   817.180407  12106.13470
# 2      No      No  1073.549164  31767.13895
# 3      No      No   529.250605  35704.49394
# 4      No      No   785.655883  38463.49588

# %%
from sklearn.preprocessing import LabelEncoder
k = LabelEncoder()
data["default"]=k.fit_transform(data["default"])

# %%
data.head()
# Out:
#    default student      balance       income
# 0        0      No   729.526495  44361.62507
# 1        0     Yes   817.180407  12106.13470
# 2        0      No  1073.549164  31767.13895
# 3        0      No   529.250605  35704.49394
# 4        0      No   785.655883  38463.49588

# %%
data["default"].value_counts()
# Out:
# 0    9667
# 1     333
# Name: default, dtype: int64

# %%
data["student"]=k.fit_transform(data["student"])

# %%
data.tail(50)
# Out:
#       default  student      balance       income
# 9950        0        0   879.624128  33682.18616
# 9951        1        0  1515.606239  48688.51209
# 9952        0        0    13.944475  31071.63429
# 9953        0        1   776.544280  14229.72812
# 9954        0        1   865.906316  18064.24399
# 9955        0        1   692.356318  18689.05214
# 9956        0        0   415.768259  38425.75950
# 9957        0        0  1765.990895  47642.42212
# 9958        0        0  1391.033877  53255.02112
# 9959        0        0     0.000000  53946.23365
# 9960        0        1   826.741213  18856.90003
# 9961        0        0   896.721925  48703.41297
# 9962        0        1  1635.175122  13518.93062
# 9963        0        0   453.648232  32178.62217
# 9964        0        0   789.551178  30777.83900
# 9965        0        1   905.142369  13485.51424
# 9966        0        0  1439.118794  20187.78769
# 9967        0        0  1092.530775  43482.78820
# ...

# %%
data["student"].value_counts()
# Out:
# 0    7056
# 1    2944
# Name: student, dtype: int64

# %%
y = data["default"]
x = data.drop("default",axis = 1)

# %%
#Split the data into train and test 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_train,y_train)
# Out:
# 0.9708970897089709

# %%
gnb.score(x_test,y_test)
# Out:
# 0.968506298740252

# %%
prediction = gnb.predict([[0,729.526495,44361.62507]])
print(f'Default Class: {prediction}')
# Out:
# Default Class: [0]
# C:\Users\Madhur Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
prediction = gnb.predict([[0,2202.462395,47287.25711]])
print(f'Default Class: {prediction}')
# Out:
# Default Class: [1]
# C:\Users\Madhur Chauhan\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
